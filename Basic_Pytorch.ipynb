# %%
# PyTorch is an open-source machine learning and deep learning framework developed by Meta (Facebook).

# %%
# It is mainly used to:

    # Build neural networks
    # Train deep learning models
    # Work with images, text, audio, and video
    # Perform GPU-accelerated computations
    # Implement models such as CNN, RNN, Transformer, ResNet, DenseNet, etc.

# %%
# torch module
    # torch	- main/core module of PyTorch.
    # torch.nn -Build neural networks   
    # torch.optim -	Contain Optimizers such as Adam
    # torch.autograd - compute gradient for optimization
    # torch.utils.data -	Dataset and DataLoader
    # torchvision	- Computer vision
    # torchvision.models - 	Pretrained CNN models
    # torchvision.transforms -	Image preprocessing/augmentation
    # torch.txt - tools and dataset for NLP
    # torch.cuda -Enable GPU accelaration for model training
    # Optuna - automatic hyperparameter tuning tools
